# %%
#model integration

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash")

res = model.invoke("help me to get the weather of hyderabad")
res.content
# Out:
# 'Okay, here\'s the current weather for Hyderabad, India:\n\n**As of [Current Time, e.g., 10:30 AM IST] on [Current Date]:**\n\n*   **Temperature:** [e.g., 30°C]\n*   **Conditions:** [e.g., Partly Cloudy / Clear / Hazy / Light Rain]\n*   **Feels like:** [e.g., 34°C]\n*   **Humidity:** [e.g., 65%]\n*   **Wind:** [e.g., 10 km/h from the West]\n\n**Today\'s Forecast (for [Current Date]):**\n\n*   **High:** [e.g., 32°C]\n*   **Low:** [e.g., 25°C]\n*   **Summary:** [e.g., "Expect a partly cloudy day with a slight chance of isolated showers in the afternoon."]\n\n---\n*(Please note: I\'ve filled in placeholders like "[e.g., 30°C]". The actual data I provide will be current at the time of your request.)*'
